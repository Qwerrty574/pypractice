# %%
import os
import pandas as pd
import numpy as np


f = os.path.join('lol.csv')
data=pd.read_csv(f, sep=',')
data.columns = ['A' + str(i) for i in range(1, 9)] + ['class']
x = data.drop(('class'), axis=1)


y=data['class']

# %%
x.head()
# Out:
#    A1   A2  A3  A4   A5    A6     A7  A8
# 0   1   85  66  29    0  26.6  0.351  31
# 1   8  183  64   0    0  23.3  0.672  32
# 2   1   89  66  23   94  28.1  0.167  21
# 3   0  137  40  35  168  43.1  2.288  33
# 4   5  116  74   0    0  25.6  0.201  30

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
#scaler=MinMaxScaler()
#x=pd.DataFrame(scaler.fit_transform(x))
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x))
x.head()
# Out:
#           0         1         2  ...         5         6         7
# 0 -0.843726 -1.122086 -0.160249  ... -0.683729 -0.364265 -0.188940
# 1  1.234240  1.944476 -0.263578  ... -1.102301  0.604701 -0.103795
# 2 -0.843726 -0.996920 -0.160249  ... -0.493469 -0.919684 -1.040393
# 3 -1.140579  0.505069 -1.503534  ...  1.409132  5.482732 -0.018650
# 4  0.343683 -0.152051  0.253070  ... -0.810569 -0.817052 -0.274086
#
# [5 rows x 8 columns]

# %%
import numpy as np
a =np.mean(x[2])
x.head()
print(a)
# Out:
# 3.3763554027082356e-16

# %%
b = np.var(x[1])
print(b)
# Out:
# 1.0000000000000016

# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from  sklearn  import  preprocessing
from sklearn.metrics import accuracy_score
clf=SVC()
rn_split=1
x_tr, x_te, y_tr, y_te=train_test_split(x,y, test_size=0.2, random_state=rn_split)
    
    # НОРМИРОВКА!!!!
standard_scaler=preprocessing.StandardScaler()
x_tr = pd.DataFrame(standard_scaler.fit_transform(x_tr))
          
x_te = pd.DataFrame(standard_scaler.transform(x_te)) 
x_tr=x_tr.reset_index(drop=True)
y_tr=y_tr.reset_index(drop=True)
y_tr=y_tr.astype('int64')
y_te=y_te.astype('int64')
clf.fit(x_tr,y_tr)
pred=clf.predict(x_te)
    #t2=time.time()
    #deltaT=t2-t1  
    #averTime=averTime+deltaT    
current_acc=accuracy_score(y_te, pred)
print(current_acc)
# Out:
# 0.7662337662337663

# %%
from sklearn.preprocessing import MinMaxScaler
max_acc=0
N=100
for i in range(N):    
    rn_split=i
    X_tr, X_te, y_tr, y_te=train_test_split(x,y, test_size=0.2, random_state=rn_split)
    
    # НОРМИРОВКА!!!!
    standard_scaler=preprocessing.StandardScaler()
    X_tr = pd.DataFrame(standard_scaler.fit_transform(X_tr))
          
    X_te = pd.DataFrame(standard_scaler.transform(X_te)) 
    X_tr=X_tr.reset_index(drop=True)
    y_tr=y_tr.reset_index(drop=True)
    y_tr=y_tr.astype('int64')
    y_te=y_te.astype('int64')
    clf.fit(X_tr,y_tr)
    pred=clf.predict(X_te)     
    current_acc=accuracy_score(y_te, pred)
    if max_acc<current_acc:
        max_acc=current_acc
        i_acc=i
print(max_acc)
# Out:
# 0.8376623376623377

# %%
import time
averTime=0
max_acc=0
N=100
for i in range(N):
    t1=time.time()    
    rn_split=i
    X_tr, X_te, y_tr, y_te=train_test_split(x,y, test_size=0.2, random_state=rn_split)
    
    # НОРМИРОВКА!!!!
    standard_scaler=preprocessing.StandardScaler()
    X_tr = pd.DataFrame(standard_scaler.fit_transform(X_tr))
          
    X_te = pd.DataFrame(standard_scaler.transform(X_te)) 
    X_tr=X_tr.reset_index(drop=True)
    y_tr=y_tr.reset_index(drop=True)
    y_tr=y_tr.astype('int64')
    y_te=y_te.astype('int64')
    clf.fit(X_tr,y_tr)
    pred=clf.predict(X_te)
    t2=time.time()
    deltaT=t2-t1  
    averTime=averTime+deltaT    
    current_acc=accuracy_score(y_te, pred)
    if max_acc<current_acc:
        max_acc=current_acc
        i_acc=i
TimeSVM=averTime/N
print(' averTime=', averTime/N)
# Out:
#  averTime= 0.01942009449005127
